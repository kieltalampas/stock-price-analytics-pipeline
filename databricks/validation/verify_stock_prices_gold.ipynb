# %% [markdown]
# MAGIC %sql
# MAGIC SELECT *
# MAGIC FROM stock_prices.stocks_dlt.fact_stock_prices_gold

# %% [markdown]
# MAGIC %sql
# MAGIC SELECT *
# MAGIC FROM stock_prices.stocks_dlt.dim_stock
