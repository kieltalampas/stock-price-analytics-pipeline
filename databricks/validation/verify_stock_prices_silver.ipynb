# %% [markdown]
# MAGIC %sql
# MAGIC SELECT *
# MAGIC FROM stock_prices.stocks_dlt.stock_prices_silver

# %% [markdown]
# MAGIC %sql
# MAGIC DESCRIBE TABLE stock_prices.stocks_dlt.stock_prices_silver
# MAGIC

# %% [markdown]
# MAGIC %sql
# MAGIC SELECT COUNT(*) FROM stock_prices.stocks_dlt.stock_prices_silver
# MAGIC

# %% [markdown]
# MAGIC %sql
# MAGIC SELECT COUNT(*) FROM stock_prices.stocks_dlt.stock_prices_silver
# MAGIC WHERE open_price IS NULL
# MAGIC    OR close_price IS NULL
# MAGIC    OR trade_date IS NULL;
